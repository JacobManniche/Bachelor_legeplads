# %%
import numpy as np
import matplotlib.pyplot as plt
from py_wake_ellipsys.wind_farm_models.ellipsys import EllipSys
from pyellipsys.inversemap import InverseMap
import xarray as xr
import pandas as pd
import os

from py_wake_postprocessor import process_rans

# %%
file = os.path.abspath('../../nc files/flowdata_2m.nc')
ds = xr.open_dataset(file)

# %%
ds_cart = process_rans(file, res=2.0, xyz=(256,256,100))

# %%
print(ds_cart)
