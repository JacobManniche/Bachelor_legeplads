# %%
from tracer import *

# %%
# Example usage of with scenario from N. Yaghoobian
P0 = [0,0,0]
V0 = initial_velocity(speed=48, angle=20) 
W0 = np.array([rpm2radps(8647), 0, 0])
wind = np.array([8, 3, 6])

# %%
from plotter import plot_trajectory

# %%
plot_trajectory(P0, V0, W0, wind)

# %%
from animate import animate

# %%
animate(P0, V0, W0, wind, dt=0.01, randomize_wind=True)
